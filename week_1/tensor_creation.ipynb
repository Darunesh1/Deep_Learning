# %% [markdown]
# <a href="https://colab.research.google.com/github/Darunesh1/Deep_Learning/blob/main/week_1/tensor_creation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

# %%
scalar_tensor = torch.tensor(7)

vector_tensor = torch.tensor([1,2,3,4,5])

matrix_tensor = torch.tensor([
    [1,2,3],
    [2,3,4],
    [8,9,10]
])
