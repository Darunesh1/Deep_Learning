# %% [markdown]
# <a href="https://colab.research.google.com/github/Darunesh1/Deep_Learning/blob/main/week_1/Environment-Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
