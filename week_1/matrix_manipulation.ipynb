# %%
import torch
import numpy as np
import pandas as pd

# %%
print(f" Version of Torch: {torch.__version__}")
print(f" Version of Numpy: {np.__version__}")
print(f" Version of Pandas: {pd.__version__}")
# Out:
#  Version of Torch: 2.10.0+cu128
#  Version of Numpy: 1.26.4
#  Version of Pandas: 2.3.3

# %%
random_tesnor = torch.rand(size=(3,4))
print(random_tesnor)
print(random_tesnor.dtype)
print(random_tesnor.dtype)
# Out:
# tensor([[0.7833, 0.0844, 0.5802, 0.6570],
#         [0.7408, 0.1520, 0.7034, 0.2005],
#         [0.5811, 0.8055, 0.1832, 0.1703]])
# torch.float32

# %%
print(torch.mean(random_tesnor))
print(torch.mean(random_tesnor))
print(torch.mean(random_tesnor))
print(torch.std(random_tesnor))
# Out:
# tensor(0.4701)
# tensor(0.4701)
# tensor(0.4701)
# tensor(0.2848)

# %% [markdown]
# ### Computer vision

# %%
random_image_size_tensor = torch.rand(size=())
